# %%
import pandas as pd

import matplotlib.pyplot as plt   

# This following is a jupyter magic command. It tells jupyter to insert 
# the plots into the notebook rather than a new window.
# %matplotlib inline

# %%
demData = pd.read_excel('democracyData.xlsx', sheet_name='data-for-countries-etc-by-year', nrows = 2338)

# %%
#demData
demData = demData.rename(columns = {'Change in democracy index (EIU)': 'demChange'})
#demData = demData.set_index('time')

dataDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
data =pd.DataFrame(dataDict)
#demData
#data

# %%
conts = [demData['geo'][0]]
for i in demData['geo']:
    if i not in conts:
        conts.append(i)
        
demData = demData.set_index('time')
#demData.head()
#conts

# %%
for i in conts:
    #df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
    #data['continent'].append([i])
    data = data.append({'country': i}, ignore_index=True)
    #for j in range(2007,2020):
data = data.set_index('country') 

#data

# %%
for i in conts:
    #print(data.head())
    for j in range(2007,2020):
        temp = 0
        #cal = data.iloc[0]['cals']
        #data.loc[i][j] = demData.iloc[j]['demChange']
        data.loc[i][j] = demData[demData['geo'].isin([i])].loc[j]['demChange']
        #data.loc[i][j] = 1
        
#data

# %%
gdpGrowth = pd.read_excel('gdp_growth_data.xlsx', header = 3)
#gdpGrowth

# %%
dropCols = []
for i in range(1960,2007):
    dropCols.append(i)
    
gdpGrowth = gdpGrowth.drop(columns = dropCols)
#gdpGrowth = gdpGrowth.drop(columns = [])
#gdpGrowth

# %%
gdpGrowth["Country Code"] = gdpGrowth["Country Code"].str.lower()
#gdpGrowth

# %%
conts2 = [gdpGrowth['Country Code'][0]]
for i in gdpGrowth['Country Code']:
    if i not in conts2:
        conts2.append(i)
        
#conts2

# %%
gdpGrowth = gdpGrowth.set_index('Country Code')
#gdpGrowth

# %%
dataDict2 = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
growthData =pd.DataFrame(dataDict2)

for i in conts:
    #df2 = pd.DataFrame([[5, 6], [7, 8]], columns=list('AB'))
    #data['continent'].append([i])
    growthData = growthData.append({'country': i}, ignore_index=True)
    #for j in range(2007,2020):
growthData = growthData.set_index('country') 

growthData
# Out:
#          2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# country
# afg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# alb       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# dza       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ago       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# arg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# ven       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# vnm       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# yem       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zmb       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# zwe       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#          2018  2019
# country
# afg       NaN   NaN
# ...

# %%
for i in conts:
    #print(data.head())
    for j in range(2007,2020):
        temp = 0
        #cal = data.iloc[0]['cals']
        #data.loc[i][j] = demData.iloc[j]['demChange']
        #data.loc[i][j] = demData[demData['name'].isin([i])].loc[j]['demChange']
        if i in conts2:
            growthData.loc[i][j] = gdpGrowth.loc[i][j]
        
growthData.head()
# Out:
#               2007      2008       2009       2010      2011      2012  \
# country
# afg      11.022774  1.594211  18.515369  11.264133 -2.681081  8.974880
# alb       6.783927  8.328036   4.048888   4.223038  2.821558  1.585156
# dza       1.808249  0.738171  -0.134668   1.746776  0.980205  1.401797
# ago       9.890012  7.116873  -2.808634   0.640294 -0.220851  4.706498
# arg       7.924238  3.029477  -6.854227   9.300128  4.788683 -2.145284
#
#              2013      2014      2015      2016      2017      2018      2019
# country
# afg      1.974169 -0.665271 -1.622887 -0.541697  0.064250 -1.195347  1.536912
# alb      1.187204  1.985426  2.516853  3.480117  3.897711  4.328396  2.676550
# dza      0.761675  1.710450  1.600478  1.104568 -0.750500 -0.811209 -1.130692
# ago      1.292041  1.219835 -2.468719 -5.816191 -3.409909 -5.162102 -3.795674
# arg      1.265685 -3.578581  1.629664 -3.110064  1.757648 -3.550091 -3.055855

# %%
dataDictFin = {'demChange':[], 'gdpChange':[]}
dataFin =pd.DataFrame(dataDictFin)
for i in conts:
    #print(data.head())
    for j in range(2007,2020):
        dataFin = dataFin.append({'demChange': data.loc[i][j], 'gdpChange': growthData.loc[i][j]}, ignore_index=True)
        #dataFin = dataFin.append({'gdpChange': growthData.loc[i][j]}, ignore_index=True)
        #growthData.loc[i][j] = gdpGrowth.loc[i][j]
        
dataFin
# Out:
#       demChange  gdpChange
# 0          -0.2  11.022774
# 1          -0.2   1.594211
# 2          -2.7  18.515369
# 3          -2.7  11.264133
# 4           0.0  -2.681081
# ...         ...        ...
# 2166        2.7   0.100456
# 2167        0.0  -0.793566
# 2168        1.1   3.186399
# 2169        0.0   3.361138
# 2170        0.0  -9.395470
#
# [2171 rows x 2 columns]

# %%
fig, ax = plt.subplots()


ax.scatter(dataFin["demChange"],dataFin["gdpChange"])

ax.axhline(y=0, color='black', linewidth=0.75)
ax.axvline(x=0, color='black', linewidth=0.75)

plt.show()

# %%
indxData = pd.read_excel('democracyData.xlsx', sheet_name='sort-data', nrows = 2006, header = 2)
#demData
indxData = indxData.rename(columns = {'Democracy Index': 'demIndx'})
#demData = demData.set_index('time')
indxData = indxData[indxData['year']==2019]

dataDict3 = {'Democracy':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}

dataIndx =pd.DataFrame(dataDict)
dataIndx = dataIndx.append({'Democracy': 'full'}, ignore_index=True)
dataIndx = dataIndx.append({'Democracy': 'flawed'}, ignore_index=True)
dataIndx = dataIndx.append({'Democracy': 'hybrid'}, ignore_index=True)
dataIndx = dataIndx.append({'Democracy': 'authoritarian'}, ignore_index=True)
dataIndx = dataIndx.set_index('Democracy')
#indxData
dataIndx
# Out:
#                country  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# Democracy
# full               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# flawed             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# hybrid             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# authoritarian      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                2016  2017  2018  2019
# Democracy
# full            NaN   NaN   NaN   NaN
# flawed          NaN   NaN   NaN   NaN
# hybrid          NaN   NaN   NaN   NaN
# authoritarian   NaN   NaN   NaN   NaN

# %%
fullIndx = indxData[indxData['demIndx'] > 80]
flawedIndx = indxData[(indxData['demIndx'] <= 80) & (indxData['demIndx'] > 60)]
hybridIndx = indxData[(indxData['demIndx'] <= 60) & (indxData['demIndx'] > 40)]
authorIndx = indxData[(indxData['demIndx']) <= 40]


#fullIndx
#flawedIndx
#hybridIndx
#authorIndx

# %%
#for i in fullIndx['geo']:
full = [fullIndx['geo'][83]]
for i in fullIndx['geo']:
    if i not in full:
        full.append(i)
        
flawed = [flawedIndx['geo'][59]]
for i in flawedIndx['geo']:
    if i not in flawed:
        flawed.append(i)
        
hybrid = [hybridIndx['geo'][23]]
for i in hybridIndx['geo']:
    if i not in hybrid:
        hybrid.append(i)
        
authoritarian = [authorIndx['geo'][11]]
for i in authorIndx['geo']:
    if i not in authoritarian:
        authoritarian.append(i)

# %%
#Full Democracies
fullDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
fullData =pd.DataFrame(fullDict)

for i in full: 
    fullData = fullData.append({'country': i}, ignore_index=True)
fullData = fullData.set_index('country')

#Flawed Democracies
flawedDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
flawedData =pd.DataFrame(flawedDict)

for i in flawed: 
    flawedData = flawedData.append({'country': i}, ignore_index=True)
flawedData = flawedData.set_index('country')

#Hybrid Democracies
hybridDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
hybridData =pd.DataFrame(hybridDict)

for i in hybrid: 
    hybridData = hybridData.append({'country': i}, ignore_index=True)
hybridData = hybridData.set_index('country')

#Authoritarian
authorDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
authorData =pd.DataFrame(authorDict)

for i in authoritarian: 
    authorData = authorData.append({'country': i}, ignore_index=True)
authorData = authorData.set_index('country')

# %%
for i in full:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            fullData.loc[i][j] = gdpGrowth.loc[i][j]
#fullData.head()

# %%
for i in flawed:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            flawedData.loc[i][j] = gdpGrowth.loc[i][j]
#flawedData.head()

# %%
for i in hybrid:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            hybridData.loc[i][j] = gdpGrowth.loc[i][j]
#hybridData.head()

# %%
for i in authoritarian:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            authorData.loc[i][j] = gdpGrowth.loc[i][j]
authorData.head()
# Out:
#               2007       2008       2009       2010      2011      2012  \
# country
# afg      11.022774   1.594211  18.515369  11.264133 -2.681081  8.974880
# ago       9.890012   7.116873  -2.808634   0.640294 -0.220851  4.706498
# aze      24.048679   8.293391   7.121820   3.549861 -2.847183  0.853886
# bhr       0.192082  -1.258589  -3.554573  -0.356145 -0.991929  1.989230
# blr       9.099460  10.581305   0.423651   7.982069  5.572386  1.780362
#
#              2013      2014      2015      2016      2017      2018      2019
# country
# afg      1.974169 -0.665271 -1.622887 -0.541697  0.064250 -1.195347  1.536912
# ago      1.292041  1.219835 -2.468719 -5.816191 -3.409909 -5.162102 -3.795674
# aze      4.483203  1.522432 -0.147025 -4.141175 -0.824348  0.624884  1.366684
# bhr      4.207499  2.706652 -0.187300 -0.359645 -0.475413 -3.108050 -2.631179
# blr      0.987444  1.634971 -3.982649 -2.648710  2.567483  3.309792  1.400048

# %%
dems = ['full','flawed','hybrid','authoritarian']
for i in dems:
    if i == 'full':
        for j in range(2007,2020):
            dataIndx.loc[i][j] = fullData.loc[:,j].mean()
    if i == 'flawed':
        for j in range(2007,2020):
            dataIndx.loc[i][j] = flawedData.loc[:,j].mean()
    if i == 'hybrid':
        for j in range(2007,2020):
            dataIndx.loc[i][j] = hybridData.loc[:,j].mean()
    if i == 'authoritarian':
        for j in range(2007,2020):
            dataIndx.loc[i][j] = authorData.loc[:,j].mean()
dataIndx.head()
#pepsico135mean = dataPepsico135.loc[:,j].mean()
# Out:
#                country      2007      2008      2009      2010      2011  \
# Democracy
# full               NaN  3.613097  0.373083 -3.530676  2.052705  1.742514
# flawed             NaN  5.331308  2.729451 -2.520464  3.661754  3.218530
# hybrid             NaN  4.803454  3.511628  0.029010  2.928015  2.528631
# authoritarian      NaN  3.832752  2.606305  0.968881  3.231246  1.813981
#
#                    2012      2013      2014      2015      2016      2017  \
# Democracy
# full           0.343760  0.907935  1.687280  2.532916  1.771468  2.054744
# flawed         2.119841  2.355989  2.254435  2.091393  1.848811  2.541763
# hybrid         2.066585  3.279857  2.439342  1.153924  1.905733  2.864774
# authoritarian  5.984235  1.115756  1.228943  0.439434  0.909533  1.184344
#
#                    2018      2019
# Democracy
# full           1.857650  1.016242
# flawed         2.336318  2.042302
# hybrid         2.638778  1.951158
# authoritarian  1.013880  0.485726

# %%
dataIndx = dataIndx.drop(columns = ['country'])
dataIndx.head()
# Out:
#                    2007      2008      2009      2010      2011      2012  \
# Democracy
# full           3.613097  0.373083 -3.530676  2.052705  1.742514  0.343760
# flawed         5.331308  2.729451 -2.520464  3.661754  3.218530  2.119841
# hybrid         4.803454  3.511628  0.029010  2.928015  2.528631  2.066585
# authoritarian  3.832752  2.606305  0.968881  3.231246  1.813981  5.984235
#
#                    2013      2014      2015      2016      2017      2018  \
# Democracy
# full           0.907935  1.687280  2.532916  1.771468  2.054744  1.857650
# flawed         2.355989  2.254435  2.091393  1.848811  2.541763  2.336318
# hybrid         3.279857  2.439342  1.153924  1.905733  2.864774  2.638778
# authoritarian  1.115756  1.228943  0.439434  0.909533  1.184344  1.013880
#
#                    2019
# Democracy
# full           1.016242
# flawed         2.042302
# hybrid         1.951158
# authoritarian  0.485726

# %%
#Full Democracies
fullDemDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
fullDemData =pd.DataFrame(fullDemDict)

for i in full: 
    fullDemData = fullDemData.append({'country': i}, ignore_index=True)
fullDemData = fullDemData.set_index('country')

#Flawed Democracies
flawedDemDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
flawedDemData =pd.DataFrame(flawedDemDict)

for i in flawed: 
    flawedDemData = flawedDemData.append({'country': i}, ignore_index=True)
flawedDemData = flawedDemData.set_index('country')

#Hybrid Democracies
hybridDemDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
hybridDemData =pd.DataFrame(hybridDemDict)

for i in hybrid: 
    hybridDemData = hybridDemData.append({'country': i}, ignore_index=True)
hybridDemData = hybridDemData.set_index('country')

#Authoritarian
authorDemDict = {'country':[], 2007:[], 2008:[], 2009:[], 2010:[], 2011:[], 2012:[], 2013:[], 
            2014:[], 2015:[], 2016:[], 2017:[], 2018:[], 2019:[]}
authorDemData =pd.DataFrame(authorDemDict)

for i in authoritarian: 
    authorDemData = authorDemData.append({'country': i}, ignore_index=True)
authorDemData = authorDemData.set_index('country')

# %%
for i in full:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            #fullDemData.loc[i][j] = gdpGrowth.loc[i][j]
            #data.loc[i][j] = demData[demData['geo'].isin([i])].loc[j]['demChange']
            fullDemData.loc[i][j] = demData[demData['geo'].isin([i])].loc[j]['demChange']
#fullData.head()

for i in flawed:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            #flawedDemData.loc[i][j] = gdpGrowth.loc[i][j]
            flawedDemData.loc[i][j] = demData[demData['geo'].isin([i])].loc[j]['demChange']
#flawedData.head()

for i in hybrid:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            hybridDemData.loc[i][j] = gdpGrowth.loc[i][j]
hybridData.head()

for i in authoritarian:
    for j in range(2007,2020):
        temp = 0
        if i in conts2:
            #authorDemData.loc[i][j] = gdpGrowth.loc[i][j]
            authorDemData.loc[i][j] = demData[demData['geo'].isin([i])].loc[j]['demChange']
#authorData.head()

# %%
dataIndx2 =pd.DataFrame(dataDict)
dataIndx2 = dataIndx2.append({'Democracy': 'full'}, ignore_index=True)
dataIndx2 = dataIndx2.append({'Democracy': 'flawed'}, ignore_index=True)
dataIndx2 = dataIndx2.append({'Democracy': 'hybrid'}, ignore_index=True)
dataIndx2 = dataIndx2.append({'Democracy': 'authoritarian'}, ignore_index=True)
dataIndx2 = dataIndx2.set_index('Democracy')

dems = ['full','flawed','hybrid','authoritarian']
for i in dems:
    if i == 'full':
        for j in range(2007,2020):
            dataIndx2.loc[i][j] = fullDemData.loc[:,j].mean()
    if i == 'flawed':
        for j in range(2007,2020):
            dataIndx2.loc[i][j] = flawedDemData.loc[:,j].mean()
    if i == 'hybrid':
        for j in range(2007,2020):
            dataIndx2.loc[i][j] = hybridDemData.loc[:,j].mean()
    if i == 'authoritarian':
        for j in range(2007,2020):
            dataIndx2.loc[i][j] = authorDemData.loc[:,j].mean()

dataIndx2 = dataIndx2.drop(columns = ['country'])
dataIndx2.head()
# Out:
#                    2007      2008      2009      2010      2011      2012  \
# Democracy
# full           0.054545  0.054545 -0.545455 -0.545455 -0.340909  0.404545
# flawed         0.265094  0.265094 -0.354717 -0.354717  0.375472  0.313208
# hybrid         4.803454  3.511628  0.029010  2.928015  2.528631  2.066585
# authoritarian  0.104630  0.104630 -0.421296 -0.421296  0.590741  0.211111
#
#                    2013      2014      2015      2016      2017      2018  \
# Democracy
# full          -0.181818  0.154545  0.027273 -0.013636 -0.045455  0.286364
# flawed         0.415094  0.067925  0.281132 -0.322642 -0.784906  0.050943
# hybrid         3.279857  2.439342  1.153924  1.905733  2.864774  2.638778
# authoritarian -0.350000  0.150000 -0.594444 -0.450000 -0.677778 -0.379630
#
#                    2019
# Democracy
# full           0.577273
# flawed         0.181132
# hybrid         1.951158
# authoritarian -0.955556

# %%
fig2, ax2 = plt.subplots(1,2, figsize = (10,4)) 

plt.ylim((-4,6))

ax2[0].plot(dataIndx.columns, dataIndx.loc['full'], color='blue', label = 'Full Democracy')  
ax2[0].plot(dataIndx.columns, dataIndx.loc['flawed'], color='green', label = 'Flawed Democracy')
ax2[0].plot(dataIndx.columns, dataIndx.loc['hybrid'], color='orange', label = 'Hybrid Democracy') 
ax2[0].plot(dataIndx.columns, dataIndx.loc['authoritarian'], color='red', label = 'Authoritarian Regime')

ax2[1].plot(dataIndx2.columns, dataIndx2.loc['full'], color='blue', label = 'Full Democracy')  
ax2[1].plot(dataIndx2.columns, dataIndx2.loc['flawed'], color='green', label = 'Flawed Democracy')
ax2[1].plot(dataIndx2.columns, dataIndx2.loc['hybrid'], color='orange', label = 'Hybrid Democracy') 
ax2[1].plot(dataIndx2.columns, dataIndx2.loc['authoritarian'], color='red', label = 'Authoritarian Regime')

ax2[0].set_ylabel('GDP Percent Growth')  
ax2[0].set_title('GDP Growth Rates of Various Types of Democracies')

ax2[1].set_ylabel('Democracy Index Percent Growth')  
ax2[1].set_title('Growth Rates of Democracy Index Over Time')

for i in range(0,2):
    ax2[i].legend(frameon=False) 
    ax2[i].axhline(y=0, color='black', linewidth=0.75) # Add a horizontal line at y=0
    ax2[i].spines['right'].set_visible(False) # get ride of the line on the right
    ax2[i].spines['top'].set_visible(False)   # get rid of the line on top



plt.show()

# %%
fig3, ax3 = plt.subplots(figsize = (8,4))

ax3.plot(dataIndx2.columns, dataIndx2.loc['full'], color='blue', label = 'Full Democracy')  
ax3.plot(dataIndx2.columns, dataIndx2.loc['flawed'], color='green', label = 'Flawed Democracy')
ax3.plot(dataIndx2.columns, dataIndx2.loc['hybrid'], color='orange', label = 'Hybrid Democracy') 
ax3.plot(dataIndx2.columns, dataIndx2.loc['authoritarian'], color='red', label = 'Authoritarian Regime')

ax3.legend(frameon=False) 
ax3.axhline(y=0, color='black', linewidth=0.75) # Add a horizontal line at y=0
ax3.spines['right'].set_visible(False) # get ride of the line on the right
ax3.spines['top'].set_visible(False)   # get rid of the line on top

ax3.set_ylabel('Democracy Index Percent Growth')  
ax3.set_title('Growth Rates of Democracy Index Over Time')

# plt.savefig('Dem_index_chg_by_regime.png')

# %%
my_fig, my_ax = plt.subplots(figsize = (8,4))
plt.ylim((-4,6))

my_ax.plot(dataIndx.columns, dataIndx.loc['full'], color='blue', label = 'Full Democracy')  
my_ax.plot(dataIndx.columns, dataIndx.loc['flawed'], color='green', label = 'Flawed Democracy')
my_ax.plot(dataIndx.columns, dataIndx.loc['hybrid'], color='orange', label = 'Hybrid Democracy') 
my_ax.plot(dataIndx.columns, dataIndx.loc['authoritarian'], color='red', label = 'Authoritarian Regime')

my_ax.set_ylabel('GDP Percent Growth')  
my_ax.set_title('GDP Growth Rates of Various Types of Democracies')

my_ax.legend(frameon=False) 
my_ax.axhline(y=0, color='black', linewidth=0.75) # Add a horizontal line at y=0
my_ax.spines['right'].set_visible(False) # get ride of the line on the right
my_ax.spines['top'].set_visible(False)   # get rid of the line on top

# plt.savefig('GDP_growth_by_regime.pdf', bbox_inches = 'tight')
